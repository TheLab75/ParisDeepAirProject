# %%
import numpy as np
import pandas as pd

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (0.13.5)
# Requirement already satisfied: numpy>=1.17 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: patsy>=0.5.2 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: scipy>=1.3 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from statsmodels) (1.9.3)
# Requirement already satisfied: pandas>=0.25 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from statsmodels) (1.5.2)
# Requirement already satisfied: packaging>=21.3 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from statsmodels) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from pandas>=0.25->statsmodels) (2022.6)
# Requirement already satisfied: six in /Users/llm/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)

# %%
# !cd ../data/pollution/2_Processed && ls -la
# Out:
# total 117576
# drwxr-xr-x@ 23 llm  staff      736 Nov 25 00:14 .
# drwxr-xr-x@ 25 llm  staff      800 Nov 25 00:14 ..
# -rw-r--r--@  1 llm  staff     6148 Nov 25 00:08 .DS_Store
# -rw-r--r--@  1 llm  staff  2561351 Nov 25 00:13 PA75001.csv
# -rw-r--r--@  1 llm  staff  2965830 Nov 25 00:13 PA75002.csv
# -rw-r--r--@  1 llm  staff  3181451 Nov 25 00:13 PA75004.csv
# -rw-r--r--@  1 llm  staff  2755954 Nov 25 00:13 PA75006.csv
# -rw-r--r--@  1 llm  staff  3343070 Nov 25 00:13 PA75007_1.csv
# -rw-r--r--@  1 llm  staff  2783824 Nov 25 00:13 PA75007_2.csv
# -rw-r--r--@  1 llm  staff  3308645 Nov 25 00:13 PA75008.csv
# -rw-r--r--@  1 llm  staff  3244208 Nov 25 00:13 PA75009.csv
# -rw-r--r--@  1 llm  staff  2881234 Nov 25 00:13 PA75012_1.csv
# -rw-r--r--@  1 llm  staff  3268030 Nov 25 00:13 PA75012_2.csv
# -rw-r--r--@  1 llm  staff  2789641 Nov 25 00:13 PA75012_3.csv
# -rw-r--r--@  1 llm  staff  2997587 Nov 25 00:13 PA75013.csv
# -rw-r--r--@  1 llm  staff  2123082 Nov 25 00:13 PA75014.csv
# -rw-r--r--@  1 llm  staff  2714631 Nov 25 00:14 PA75015.csv
# -rw-r--r--@  1 llm  staff  4028449 Nov 25 00:14 PA75016.csv
# -rw-r--r--@  1 llm  staff  3225916 Nov 25 00:14 PA75018.csv
# -rw-r--r--@  1 llm  staff  3119381 Nov 25 00:14 PA92220.csv
# -rw-r--r--@  1 llm  staff  2307843 Nov 25 00:14 PA92800.csv
# -rw-r--r--@  1 llm  staff  3321925 Nov 25 00:14 PA93300.csv
# -rw-r--r--@  1 llm  staff  3227569 Nov 25 00:14 PA93500.csv

# %%
file_list =  !find ../data/Pollution/2_Processed | grep .csv

# %%
file_list = file_list.sort()
file_list
# Out:
# ['../data/Pollution/2_Processed/PA75001.csv',
#  '../data/Pollution/2_Processed/PA75002.csv',
#  '../data/Pollution/2_Processed/PA75004.csv',
#  '../data/Pollution/2_Processed/PA75006.csv',
#  '../data/Pollution/2_Processed/PA75007_1.csv',
#  '../data/Pollution/2_Processed/PA75007_2.csv',
#  '../data/Pollution/2_Processed/PA75008.csv',
#  '../data/Pollution/2_Processed/PA75009.csv',
#  '../data/Pollution/2_Processed/PA75012_1.csv',
#  '../data/Pollution/2_Processed/PA75012_2.csv',
#  '../data/Pollution/2_Processed/PA75012_3.csv',
#  '../data/Pollution/2_Processed/PA75013.csv',
#  '../data/Pollution/2_Processed/PA75014.csv',
#  '../data/Pollution/2_Processed/PA75015.csv',
#  '../data/Pollution/2_Processed/PA75016.csv',
#  '../data/Pollution/2_Processed/PA75018.csv',
#  '../data/Pollution/2_Processed/PA92220.csv',
#  '../data/Pollution/2_Processed/PA92800.csv',
#  '../data/Pollution/2_Processed/PA93300.csv',
#  '../data/Pollution/2_Processed/PA93500.csv']

# %%
PA75001 = pd.read_csv(file_list[0]).copy()
PA75001 = PA75001.drop(columns=("Unnamed: 0"))
PA75001
# Out:
#                     Date_time     CO  PM10  PM25   NO2    NO   NOX   O3  \
# 0      2019/01/01 01:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 1      2019/01/01 02:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 2      2019/01/01 03:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 3      2019/01/01 04:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 4      2019/01/01 05:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# ...                       ...    ...   ...   ...   ...   ...   ...  ...
# 33907  2022/11/13 20:00:00+00  0.362  22.5  19.9  25.4  15.2  48.7  0.1
# 33908  2022/11/13 21:00:00+00  0.360  23.6  21.4  28.5  12.4  47.4  0.1
# 33909  2022/11/13 22:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 33910  2022/11/13 23:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 33911  2022/11/14 00:00:00+00    NaN   NaN   NaN   NaN   NaN   NaN  NaN
#
#          Station_name Station_type
# 0      75001 - Halles       Urbain
# 1      75001 - Halles       Urbain
# 2      75001 - Halles       Urbain
# 3      75001 - Halles       Urbain
# 4      75001 - Halles       Urbain
# ...               ...          ...
# 33907  75001 - Halles       Urbain
# 33908  75001 - Halles       Urbain
# 33909  75001 - Halles       Urbain
# 33910  75001 - Halles       Urbain
# 33911  75001 - Halles       Urbain
#
# [33912 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import qqplot
import pandas as pd

def turbo_plot(X):
    fig = plt.figure(constrained_layout=True,figsize=(15,120))
    subfigs = fig.subfigures(X.shape[1], 1,squeeze=False,hspace=20)
    for outerind, subfig in enumerate(subfigs.flat):
        subfig.suptitle(f'Subfig {X.columns[outerind]}')
        axs = subfig.subplots(1, 3)
        sns.histplot(data = X, x = X.columns[outerind], kde=True, ax = axs[0])
        sns.boxplot(data = X, x = X.columns[outerind], ax = axs[1])
        qqplot(X[X.columns[outerind]],line='s',ax=axs[2])
    return plt.show()

# %%
turbo_plot(PA75001)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 turbo_plot(PA75001)
#
# Cell In [7], line 12, in turbo_plot(X)
#      10 subfig.suptitle(f'Subfig {X.columns[outerind]}')
#      11 axs = subfig.subplots(1, 3)
# ---> 12 sns.histplot(data = X, x = X.columns[outerind], kde=True, ax = axs[0])
#      13 sns.boxplot(data = X, x = X.columns[outerind], ax = axs[1])
#      14 qqplot(X[X.columns[outerind]],line='s',ax=axs[2])
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/seaborn/distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
#    1436         shrink=shrink,
#    1437         common_norm=common_norm,
#    1438         common_bins=common_bins,
#    1439         kde=kde,
#    1440         kde_kws=kde_kws,
#    1441         color=color,
#    1442         legend=legend,
#    1443         estimate_kws=estimate_kws,
#    1444         line_kws=line_kws,
#    1445         **kwargs,
#    1446     )
#    1448 else:
#    1450     p.plot_bivariate_histogram(
#    1451         common_bins=common_bins,
#    1452         common_norm=common_norm,
#    (...)
#    1462         **kwargs,
#    1463     )
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/seaborn/distributions.py:575, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     570 if element == "bars":
#     571
#     572     # Use matplotlib bar plotting
#     574     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 575     artists = plot_func(
#     576         hist["edges"],
#     577         hist["heights"] - bottom,
#     578         hist["widths"],
#     579         bottom,
#     580         align="edge",
#     581         **artist_kws,
#     582     )
#     584     for bar in artists:
#     585         if self.data_variable == "x":
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2468, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2466     else:  # horizontal
#    2467         r.sticky_edges.x.append(l)
# -> 2468     self.add_patch(r)
#    2469     patches.append(r)
#    2471 if xerr is not None or yerr is not None:
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:2415, in _AxesBase.add_patch(self, p)
#    2413 if p.get_clip_path() is None:
#    2414     p.set_clip_path(self.patch)
# -> 2415 self._update_patch_limits(p)
#    2416 self._children.append(p)
#    2417 p._remove_method = self._children.remove
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:2447, in _AxesBase._update_patch_limits(self, patch)
#    2444     vertices = np.row_stack(vertices)
#    2446 patch_trf = patch.get_transform()
# -> 2447 updatex, updatey = patch_trf.contains_branch_seperately(self.transData)
#    2448 if not (updatex or updatey):
#    2449     return
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:1411, in Transform.contains_branch_seperately(self, other_transform)
#    1407     raise ValueError('contains_branch_seperately only supports '
#    1408                      'transforms with 2 output dimensions')
#    1409 # for a non-blended transform each separate dimension is the same, so
#    1410 # just return the appropriate shape.
# -> 1411 return [self.contains_branch(other_transform)] * 2
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:1390, in Transform.contains_branch(self, other)
#    1387     return False
#    1389 # check that a subtree is equal to other (starting from self)
# -> 1390 for _, sub_tree in self._iter_break_from_left_to_right():
#    1391     if sub_tree == other:
#    1392         return True
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:2405, in CompositeGenericTransform._iter_break_from_left_to_right(self)
#    2403 def _iter_break_from_left_to_right(self):
#    2404     for left, right in self._a._iter_break_from_left_to_right():
# -> 2405         yield left, right + self._b
#    2406     for left, right in self._b._iter_break_from_left_to_right():
#    2407         yield self._a + left, right
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:1342, in Transform.__add__(self, other)
#    1335 def __add__(self, other):
#    1336     """
#    1337     Compose two transforms together so that *self* is followed by *other*.
#    1338
#    1339     ``A + B`` returns a transform ``C`` so that
#    1340     ``C.transform(x) == B.transform(A.transform(x))``.
#    1341     """
# -> 1342     return (composite_transform_factory(self, other)
#    1343             if isinstance(other, Transform) else
#    1344             NotImplemented)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:2532, in composite_transform_factory(a, b)
#    2530 elif isinstance(a, Affine2D) and isinstance(b, Affine2D):
#    2531     return CompositeAffine2D(a, b)
# -> 2532 return CompositeGenericTransform(a, b)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:2370, in CompositeGenericTransform.__init__(self, a, b, **kwargs)
#    2368 self._a = a
#    2369 self._b = b
# -> 2370 self.set_children(a, b)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/transforms.py:209, in TransformNode.set_children(self, *children)
#     201 # Parents are stored as weak references, so that if the
#     202 # parents are destroyed, references from the children won't
#     203 # keep them alive.
#     204 for child in children:
#     205     # Use weak references so this dictionary won't keep obsolete nodes
#     206     # alive; the callback deletes the dictionary entry. This is a
#     207     # performance improvement over using WeakValueDictionary.
#     208     ref = weakref.ref(
# --> 209         self, lambda _, pop=child._parents.pop, k=id(self): pop(k))
#     210     child._parents[id(self)] = ref
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x1132d9120> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/pyplot.py:119, in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
#     118     if matplotlib.is_interactive():
# --> 119         draw_all()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2054, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    2052 if not self._is_idle_drawing:
#    2053     with self._idle_draw_cntx():
# -> 2054         self.draw(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:405, in FigureCanvasAgg.draw(self)
#     401 # Acquire a lock on the shared font cache.
#     402 with RendererAgg.lock, \
#     403      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404       else nullcontext()):
# --> 405     self.figure.draw(self.renderer)
#     406     # A GUI class may be need to update a window using this draw, so
#     407     # don't forget to call the superclass.
#     408     super().draw()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/figure.py:3065, in Figure.draw(self, renderer)
#    3063 if self.axes and self.get_layout_engine() is not None:
#    3064     try:
# -> 3065         self.get_layout_engine().execute(self)
#    3066     except ValueError:
#    3067         pass
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/layout_engine.py:255, in ConstrainedLayoutEngine.execute(self, fig)
#     252 w_pad = self._params['w_pad'] / width
#     253 h_pad = self._params['h_pad'] / height
# --> 255 return do_constrained_layout(fig, w_pad=w_pad, h_pad=h_pad,
#     256                              wspace=self._params['wspace'],
#     257                              hspace=self._params['hspace'],
#     258                              rect=self._params['rect'],
#     259                              compress=self._compress)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:119, in do_constrained_layout(fig, h_pad, w_pad, hspace, wspace, rect, compress)
#     109     return
#     111 for _ in range(2):
#     112     # do the algorithm twice.  This has to be done because decorations
#     113     # change size after the first re-position (i.e. x/yticklabels get
#    (...)
#     117     # make margins for all the axes and subfigures in the
#     118     # figure.  Add margins for colorbars...
# --> 119     make_layout_margins(layoutgrids, fig, renderer, h_pad=h_pad,
#     120                         w_pad=w_pad, hspace=hspace, wspace=wspace)
#     121     make_margin_suptitles(layoutgrids, fig, renderer, h_pad=h_pad,
#     122                           w_pad=w_pad)
#     124     # if a layout is such that a columns (or rows) margin has no
#     125     # constraints, we need to make all such instances in the grid
#     126     # match in margin size.
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:351, in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     349 for sfig in fig.subfigs:  # recursively make child panel margins
#     350     ss = sfig._subplotspec
# --> 351     make_layout_margins(layoutgrids, sfig, renderer,
#     352                         w_pad=w_pad, h_pad=h_pad,
#     353                         hspace=hspace, wspace=wspace)
#     355     margins = get_margin_from_padding(sfig, w_pad=0, h_pad=0,
#     356                                       hspace=hspace, wspace=wspace)
#     357     layoutgrids[sfig].parent.edit_outer_margin_mins(margins, ss)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:371, in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     367     return
#     369 margin = get_margin_from_padding(ax, w_pad=w_pad, h_pad=h_pad,
#     370                                  hspace=hspace, wspace=wspace)
# --> 371 pos, bbox = get_pos_and_bbox(ax, renderer)
#     372 # the margin is the distance between the bounding box of the axes
#     373 # and its position (plus the padding from above)
#     374 margin['left'] += pos.x0 - bbox.x0
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:600, in get_pos_and_bbox(ax, renderer)
#     598 # pos is in panel co-ords, but we need in figure for the layout
#     599 pos = pos.transformed(fig.transSubfigure - fig.transFigure)
# --> 600 tightbbox = martist._get_tightbbox_for_layout_only(ax, renderer)
#     601 if tightbbox is None:
#     602     bbox = pos
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:1378, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1372 """
#    1373 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1374 *for_layout_only* kwarg; this helper tries to uses the kwarg but skips it
#    1375 when encountering third-party subclasses that do not support it.
#    1376 """
#    1377 try:
# -> 1378     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1379 except TypeError:
#    1380     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:4428, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4426 for axis in self._axis_map.values():
#    4427     if self.axison and axis.get_visible():
# -> 4428         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4429         if ba:
#    4430             bb.append(ba)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:1378, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1372 """
#    1373 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1374 *for_layout_only* kwarg; this helper tries to uses the kwarg but skips it
#    1375 when encountering third-party subclasses that do not support it.
#    1376 """
#    1377 try:
# -> 1378     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1379 except TypeError:
#    1380     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1251, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1249 if renderer is None:
#    1250     renderer = self.figure._get_renderer()
# -> 1251 ticks_to_draw = self._update_ticks()
#    1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1192, in Axis._update_ticks(self)
#    1190 major_locs = self.get_majorticklocs()
#    1191 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1192 major_ticks = self.get_major_ticks(len(major_locs))
#    1193 self.major.formatter.set_locs(major_locs)
#    1194 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1536, in Axis.get_major_ticks(self, numticks)
#    1534     tick = self._get_tick(major=True)
#    1535     self.majorTicks.append(tick)
# -> 1536     self._copy_tick_props(self.majorTicks[0], tick)
#    1538 return self.majorTicks[:numticks]
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1504, in Axis._copy_tick_props(self, src, dest)
#    1502 dest.label2.update_from(src.label2)
#    1503 dest.tick1line.update_from(src.tick1line)
# -> 1504 dest.tick2line.update_from(src.tick2line)
#    1505 dest.gridline.update_from(src.gridline)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/lines.py:1339, in Line2D.update_from(self, other)
#    1336 self._solidjoinstyle = other._solidjoinstyle
#    1338 self._linestyle = other._linestyle
# -> 1339 self._marker = MarkerStyle(marker=other._marker)
#    1340 self._drawstyle = other._drawstyle
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/markers.py:355, in MarkerStyle._set_marker(self, marker)
#     352     self._marker_function = getattr(
#     353         self, '_set_' + self.markers[marker])
#     354 elif isinstance(marker, MarkerStyle):
# --> 355     self.__dict__ = copy.deepcopy(marker.__dict__)
#     357 else:
#     358     try:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 y = {}
#     229 memo[id(x)] = y
# --> 230 for key, value in x.items():
#     231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x11c79cb80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
#      91             figure_manager.canvas.figure,
#      92             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93         )
#      94 finally:
#      95     show._to_draw = []
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/IPython/core/formatters.py:177, in DisplayFormatter.format(self, obj, include, exclude)
#     175 md = None
#     176 try:
# --> 177     data = formatter(obj)
#     178 except:
#     179     # FIXME: log the exception
#     180     raise
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/IPython/core/formatters.py:221, in catch_format_error(method, self, *args, **kwargs)
#     219 """show traceback on failed format call"""
#     220 try:
# --> 221     r = method(self, *args, **kwargs)
#     222 except NotImplementedError:
#     223     # don't warn on NotImplementedErrors
#     224     return self._check_return(None, args[0])
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/IPython/core/formatters.py:338, in BaseFormatter.__call__(self, obj)
#     336     pass
#     337 else:
# --> 338     return printer(obj)
#     339 # Finally look for special method names
#     340 method = get_real_method(obj, self.print_method)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/backend_bases.py:2314, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2308     renderer = _get_renderer(
#    2309         self.figure,
#    2310         functools.partial(
#    2311             print_method, orientation=orientation)
#    2312     )
#    2313     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2314         self.figure.draw(renderer)
#    2316 if bbox_inches:
#    2317     if bbox_inches == "tight":
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/figure.py:3065, in Figure.draw(self, renderer)
#    3063 if self.axes and self.get_layout_engine() is not None:
#    3064     try:
# -> 3065         self.get_layout_engine().execute(self)
#    3066     except ValueError:
#    3067         pass
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/layout_engine.py:255, in ConstrainedLayoutEngine.execute(self, fig)
#     252 w_pad = self._params['w_pad'] / width
#     253 h_pad = self._params['h_pad'] / height
# --> 255 return do_constrained_layout(fig, w_pad=w_pad, h_pad=h_pad,
#     256                              wspace=self._params['wspace'],
#     257                              hspace=self._params['hspace'],
#     258                              rect=self._params['rect'],
#     259                              compress=self._compress)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:119, in do_constrained_layout(fig, h_pad, w_pad, hspace, wspace, rect, compress)
#     109     return
#     111 for _ in range(2):
#     112     # do the algorithm twice.  This has to be done because decorations
#     113     # change size after the first re-position (i.e. x/yticklabels get
#    (...)
#     117     # make margins for all the axes and subfigures in the
#     118     # figure.  Add margins for colorbars...
# --> 119     make_layout_margins(layoutgrids, fig, renderer, h_pad=h_pad,
#     120                         w_pad=w_pad, hspace=hspace, wspace=wspace)
#     121     make_margin_suptitles(layoutgrids, fig, renderer, h_pad=h_pad,
#     122                           w_pad=w_pad)
#     124     # if a layout is such that a columns (or rows) margin has no
#     125     # constraints, we need to make all such instances in the grid
#     126     # match in margin size.
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:351, in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     349 for sfig in fig.subfigs:  # recursively make child panel margins
#     350     ss = sfig._subplotspec
# --> 351     make_layout_margins(layoutgrids, sfig, renderer,
#     352                         w_pad=w_pad, h_pad=h_pad,
#     353                         hspace=hspace, wspace=wspace)
#     355     margins = get_margin_from_padding(sfig, w_pad=0, h_pad=0,
#     356                                       hspace=hspace, wspace=wspace)
#     357     layoutgrids[sfig].parent.edit_outer_margin_mins(margins, ss)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:371, in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     367     return
#     369 margin = get_margin_from_padding(ax, w_pad=w_pad, h_pad=h_pad,
#     370                                  hspace=hspace, wspace=wspace)
# --> 371 pos, bbox = get_pos_and_bbox(ax, renderer)
#     372 # the margin is the distance between the bounding box of the axes
#     373 # and its position (plus the padding from above)
#     374 margin['left'] += pos.x0 - bbox.x0
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/_constrained_layout.py:600, in get_pos_and_bbox(ax, renderer)
#     598 # pos is in panel co-ords, but we need in figure for the layout
#     599 pos = pos.transformed(fig.transSubfigure - fig.transFigure)
# --> 600 tightbbox = martist._get_tightbbox_for_layout_only(ax, renderer)
#     601 if tightbbox is None:
#     602     bbox = pos
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:1378, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1372 """
#    1373 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1374 *for_layout_only* kwarg; this helper tries to uses the kwarg but skips it
#    1375 when encountering third-party subclasses that do not support it.
#    1376 """
#    1377 try:
# -> 1378     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1379 except TypeError:
#    1380     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axes/_base.py:4428, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4426 for axis in self._axis_map.values():
#    4427     if self.axison and axis.get_visible():
# -> 4428         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4429         if ba:
#    4430             bb.append(ba)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/artist.py:1378, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1372 """
#    1373 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1374 *for_layout_only* kwarg; this helper tries to uses the kwarg but skips it
#    1375 when encountering third-party subclasses that do not support it.
#    1376 """
#    1377 try:
# -> 1378     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1379 except TypeError:
#    1380     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1251, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1249 if renderer is None:
#    1250     renderer = self.figure._get_renderer()
# -> 1251 ticks_to_draw = self._update_ticks()
#    1253 self._update_label_position(renderer)
#    1255 # go back to just this axis's tick labels
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1192, in Axis._update_ticks(self)
#    1190 major_locs = self.get_majorticklocs()
#    1191 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1192 major_ticks = self.get_major_ticks(len(major_locs))
#    1193 self.major.formatter.set_locs(major_locs)
#    1194 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1536, in Axis.get_major_ticks(self, numticks)
#    1534     tick = self._get_tick(major=True)
#    1535     self.majorTicks.append(tick)
# -> 1536     self._copy_tick_props(self.majorTicks[0], tick)
#    1538 return self.majorTicks[:numticks]
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/axis.py:1505, in Axis._copy_tick_props(self, src, dest)
#    1503 dest.tick1line.update_from(src.tick1line)
#    1504 dest.tick2line.update_from(src.tick2line)
# -> 1505 dest.gridline.update_from(src.gridline)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/lines.py:1339, in Line2D.update_from(self, other)
#    1336 self._solidjoinstyle = other._solidjoinstyle
#    1338 self._linestyle = other._linestyle
# -> 1339 self._marker = MarkerStyle(marker=other._marker)
#    1340 self._drawstyle = other._drawstyle
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/markers.py:355, in MarkerStyle._set_marker(self, marker)
#     352     self._marker_function = getattr(
#     353         self, '_set_' + self.markers[marker])
#     354 elif isinstance(marker, MarkerStyle):
# --> 355     self.__dict__ = copy.deepcopy(marker.__dict__)
#     357 else:
#     358     try:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/copy.py:153, in deepcopy(x, memo, _nil)
#     151 copier = getattr(x, "__deepcopy__", None)
#     152 if copier is not None:
# --> 153     y = copier(memo)
#     154 else:
#     155     reductor = dispatch_table.get(cls)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/matplotlib/path.py:281, in Path.__deepcopy__(self, memo)
#     275     """
#     276     Return a shallow copy of the `Path`, which will share the
#     277     vertices and codes with the source `Path`.
#     278     """
#     279     return copy.copy(self)
# --> 281 def __deepcopy__(self, memo=None):
#     282     """
#     283     Return a deepcopy of the `Path`.  The `Path` will not be
#     284     readonly, even if the source `Path` is.
#     285     """
#     286     # Deepcopying arrays (vertices, codes) strips the writeable=False flag.
#
# KeyboardInterrupt:
