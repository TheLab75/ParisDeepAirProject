# %%
import pandas as pd 

df_test = pd.read_csv("../../data/pollution/2_Processed/PA75013.csv").copy()
df_test
# Out:
#                     Date_time  PM25  PM10   NO2    O3  SO2     Station_name  \
# 0      2018/01/01 01:00:00+00   NaN   NaN   9.0  73.0  NaN  75013 - Eastman
# 1      2018/01/01 02:00:00+00   NaN   NaN   9.0  73.0  NaN  75013 - Eastman
# 2      2018/01/01 03:00:00+00   NaN   NaN  11.0  70.0  NaN  75013 - Eastman
# 3      2018/01/01 04:00:00+00   NaN   NaN  11.0  67.0  NaN  75013 - Eastman
# 4      2018/01/01 05:00:00+00   NaN   NaN  10.0  66.0  NaN  75013 - Eastman
# ...                       ...   ...   ...   ...   ...  ...              ...
# 42667  2022/11/13 20:00:00+00   NaN   NaN  25.1   1.9  NaN  75013 - Eastman
# 42668  2022/11/13 21:00:00+00   NaN   NaN  27.3   1.7  NaN  75013 - Eastman
# 42669  2022/11/13 22:00:00+00   NaN   NaN   NaN   NaN  NaN  75013 - Eastman
# 42670  2022/11/13 23:00:00+00   NaN   NaN   NaN   NaN  NaN  75013 - Eastman
# 42671  2022/11/14 00:00:00+00   NaN   NaN   NaN   NaN  NaN  75013 - Eastman
#
#       Station_type
# 0           Urbain
# ...

# %%
from workflow.preprocessing import preprocess_without_scaling
df_test_preprocessed_w_scaling = preprocess_without_scaling(df_test)
df_test_preprocessed_w_scaling
# Out:
# You have dropped PM25 with 100.0% of NA
# You have dropped PM10 with 100.0% of NA
# You have dropped SO2 with 100.0% of NA
# You have processed                     Date_time   NO2    O3
# 0      2018/01/01 01:00:00+00   9.0  73.0
# 1      2018/01/01 02:00:00+00   9.0  73.0
# 2      2018/01/01 03:00:00+00  11.0  70.0
# 3      2018/01/01 04:00:00+00  11.0  67.0
# 4      2018/01/01 05:00:00+00  10.0  66.0
# ...                       ...   ...   ...
# 42642  2022/11/12 19:00:00+00  46.2   1.8
# 42643  2022/11/12 20:00:00+00  47.4   1.7
# 42644  2022/11/12 21:00:00+00  42.9   1.7
# 42645  2022/11/12 22:00:00+00  40.1   1.5
# 42646  2022/11/12 23:00:00+00  31.7   1.7
#
# [42647 rows x 3 columns] without scaling it, now you can play with data viz functions
#        Date_time   NO2    O3  ATMO
# 0     2018/01/01  24.0  73.0   0.0
# 1     2018/01/02  55.0  65.0   0.0
# 2     2018/01/03  33.0  75.0   0.0
# 3     2018/01/04  47.0  62.0   0.0
# 4     2018/01/05  78.0  77.0   0.0
# ...

# %%
from workflow.data_viz import data_viz

data_viz_test = data_viz(df_test_preprocessed_w_scaling)
data_viz_test
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df["Date_time"].dt.week
#       Date_time   NO2    O3  ATMO  year  week  day  month  weekday_name
# 0    2018-01-01  24.0  73.0   0.0  2018     1    1      1             0
# 1    2018-01-02  55.0  65.0   0.0  2018     1    2      1             1
# 2    2018-01-03  33.0  75.0   0.0  2018     1    3      1             2
# 3    2018-01-04  47.0  62.0   0.0  2018     1    4      1             3
# 4    2018-01-05  78.0  77.0   0.0  2018     1    5      1             4
# ...         ...   ...   ...   ...   ...   ...  ...    ...           ...
# 1772 2022-11-08  43.0  54.1   0.0  2022    45    8     11             1
# 1773 2022-11-09  68.3  54.9   0.0  2022    45    9     11             2
# 1774 2022-11-10  49.5  42.9   0.0  2022    45   10     11             3
# ...

# %%
from workflow.data_viz import plot_pollutant_v1
from workflow.data_viz import plot_pollutant_v2


plot_pollutant_v1(data_viz_test,"NO2","month")
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:38: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_groupby = df.groupby(by=["year",period],as_index=False).mean()
