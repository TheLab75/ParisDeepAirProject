# %%
import pandas as pd 
# %load_ext autoreload
# %autoreload 2
#Imports de base
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#Import du fichier à analyser
df = pd.read_csv("/Users/Edouard_1/code/TheLab75/ParisDeepAirProject/data/pollution/2_Processed/PA75016.csv").copy()


df
# Out:
#                     Date_time  PM25  PM10   NO2  O3  SO2  \
# 0      2018/01/01 01:00:00+00   NaN   NaN   NaN NaN  NaN
# 1      2018/01/01 02:00:00+00   NaN   NaN   NaN NaN  NaN
# 2      2018/01/01 03:00:00+00   NaN   NaN   NaN NaN  NaN
# 3      2018/01/01 04:00:00+00   NaN   NaN   NaN NaN  NaN
# 4      2018/01/01 05:00:00+00   NaN   NaN   NaN NaN  NaN
# ...                       ...   ...   ...   ...  ..  ...
# 42571  2022/11/14 20:00:00+00  14.5  18.8  41.5 NaN  NaN
# 42572  2022/11/14 21:00:00+00   NaN   NaN  34.5 NaN  NaN
# 42573  2022/11/14 22:00:00+00   NaN   NaN   NaN NaN  NaN
# 42574  2022/11/14 23:00:00+00   NaN   NaN   NaN NaN  NaN
# 42575  2022/11/15 00:00:00+00   NaN   NaN   NaN NaN  NaN
#
#                 Station_name Station_type
# 0      75016 - Porte Auteuil      Traffic
# 1      75016 - Porte Auteuil      Traffic
# 2      75016 - Porte Auteuil      Traffic
# 3      75016 - Porte Auteuil      Traffic
# 4      75016 - Porte Auteuil      Traffic
# ...

# %%
from workflow.preprocessing import preprocess_without_scaling

df_preproc = preprocess_without_scaling(df)
df_preproc
# Out:
# You have dropped O3 with 100.0% of NA
# You have dropped SO2 with 40.2% of NA
# You have processed the dataframe without scaling it, now you can play with data viz functions
#        Date_time   PM25   PM10   NO2  ATMO
# 0     2018/01/01  13.00  29.90  71.1     0
# 1     2018/01/02  13.00  29.90  71.1     0
# 2     2018/01/03  13.00  29.90  71.1     0
# 3     2018/01/04  13.00  29.90  71.1     0
# 4     2018/01/05  12.83  28.54  71.1     0
# ...          ...    ...    ...   ...   ...
# 1770  2022/11/09   9.46  20.89  84.7     0
# 1771  2022/11/10  13.10  24.36  86.4     0
# 1772  2022/11/11  10.79  15.25  52.5     0
# 1773  2022/11/12  23.87  37.09  97.0     1
# 1774  2022/11/13  24.85  34.48  73.3     1
#
# [1775 rows x 5 columns]

# %%
from workflow.data_viz import data_viz

df_preproc_viz = data_viz(df_preproc)
df_preproc_viz
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df["Date_time"].dt.week
#       Date_time   PM25   PM10   NO2  ATMO  year  week  day  month  \
# 0    2018-01-01  13.00  29.90  71.1     0  2018     1    1      1
# 1    2018-01-02  13.00  29.90  71.1     0  2018     1    2      1
# 2    2018-01-03  13.00  29.90  71.1     0  2018     1    3      1
# 3    2018-01-04  13.00  29.90  71.1     0  2018     1    4      1
# 4    2018-01-05  12.83  28.54  71.1     0  2018     1    5      1
# ...         ...    ...    ...   ...   ...   ...   ...  ...    ...
# 1770 2022-11-09   9.46  20.89  84.7     0  2022    45    9     11
# 1771 2022-11-10  13.10  24.36  86.4     0  2022    45   10     11
# 1772 2022-11-11  10.79  15.25  52.5     0  2022    45   11     11
# 1773 2022-11-12  23.87  37.09  97.0     1  2022    45   12     11
# ...

# %%
df_preproc_viz.groupby(by=["month"],as_index=False).mean()
# Out:
# /var/folders/5r/4vh837mj0yz7906w_9ntwqfm0000gn/T/ipykernel_11834/3708451382.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_preproc_viz.groupby(by=["month"],as_index=False).mean()
#     month       PM25       PM10         NO2      ATMO         year       week  \
# 0       1  18.292194  35.117290  103.078710  1.206452  2020.000000   4.354839
# 1       2  17.289786  39.344500  115.160714  1.221429  2019.992857   6.892857
# 2       3  18.437806  39.321677  116.990968  1.419355  2020.000000  11.116129
# 3       4  16.077200  37.164400  117.620000  1.320000  2020.000000  15.473333
# 4       5  14.198839  32.656258  108.871613  1.077419  2020.000000  19.825806
# 5       6  13.660867  31.608933  111.185333  1.106667  2020.000000  24.186667
# ...

# %%
from workflow.preprocessing import preprocess

df_test = preprocess(df)
df_test
# Out:
# You have dropped O3 with 100.0% of NA
# You have dropped SO2 with 40.2% of NA
# ['PM25', 'PM10', 'NO2', 3]
# DataFrame is processed, you can play with it !
#                 PM25      PM10       NO2  Pollution_peak  ATMO  sin_Month  \
# Date_time
# 2018-01-01 -0.001422 -0.048074 -0.840686             0.0     0   0.000000
# 2018-01-02 -0.001422 -0.048074 -0.840686             0.0     0   0.000000
# 2018-01-03 -0.001422 -0.048074 -0.840686             0.0     0   0.000000
# 2018-01-04 -0.001422 -0.048074 -0.840686             0.0     0   0.000000
# 2018-01-05 -0.025605 -0.131895 -0.840686             0.0     0   0.000000
# ...              ...       ...       ...             ...   ...        ...
# 2022-11-09 -0.504979 -0.603390 -0.507353             0.0     0  -0.866025
# 2022-11-10  0.012802 -0.389522 -0.465686             0.0     0  -0.866025
# 2022-11-11 -0.315789 -0.951002 -1.296569             0.0     0  -0.866025
# ...
