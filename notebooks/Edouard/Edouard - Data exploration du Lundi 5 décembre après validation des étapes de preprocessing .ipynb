# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd 

df_13 = pd.read_csv("../../data/pollution/2_Processed/PA75016.csv").copy()
df_13
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#                     Date_time  PM25  PM10   NO2  O3  SO2  \
# 0      2018/01/01 01:00:00+00   NaN   NaN   NaN NaN  NaN
# 1      2018/01/01 02:00:00+00   NaN   NaN   NaN NaN  NaN
# 2      2018/01/01 03:00:00+00   NaN   NaN   NaN NaN  NaN
# 3      2018/01/01 04:00:00+00   NaN   NaN   NaN NaN  NaN
# 4      2018/01/01 05:00:00+00   NaN   NaN   NaN NaN  NaN
# ...                       ...   ...   ...   ...  ..  ...
# 42571  2022/11/14 20:00:00+00  14.5  18.8  41.5 NaN  NaN
# 42572  2022/11/14 21:00:00+00   NaN   NaN  34.5 NaN  NaN
# 42573  2022/11/14 22:00:00+00   NaN   NaN   NaN NaN  NaN
# 42574  2022/11/14 23:00:00+00   NaN   NaN   NaN NaN  NaN
# 42575  2022/11/15 00:00:00+00   NaN   NaN   NaN NaN  NaN
#
#                 Station_name Station_type
# 0      75016 - Porte Auteuil      Traffic
# 1      75016 - Porte Auteuil      Traffic
# 2      75016 - Porte Auteuil      Traffic
# 3      75016 - Porte Auteuil      Traffic
# 4      75016 - Porte Auteuil      Traffic
# ...                      ...          ...
# 42571  75016 - Porte Auteuil      Traffic
# 42572  75016 - Porte Auteuil      Traffic
# 42573  75016 - Porte Auteuil      Traffic
# 42574  75016 - Porte Auteuil      Traffic
# 42575  75016 - Porte Auteuil      Traffic
#
# [42576 rows x 8 columns]

# %%
from workflow.preprocessing import preprocess_without_scaling

df_13_preprocessed_w_scaling = preprocess_without_scaling(df_13)
df_13_preprocessed_w_scaling
# Out:
# You have dropped O3 with 100.0% of NA
# You have dropped SO2 with 40.2% of NA
# You have processed                     Date_time  PM25  PM10   NO2
# 0      2018/01/01 01:00:00+00   NaN   NaN   NaN
# 1      2018/01/01 02:00:00+00   NaN   NaN   NaN
# 2      2018/01/01 03:00:00+00   NaN   NaN   NaN
# 3      2018/01/01 04:00:00+00   NaN   NaN   NaN
# 4      2018/01/01 05:00:00+00   NaN   NaN   NaN
# ...                       ...   ...   ...   ...
# 42546  2022/11/13 19:00:00+00  18.5  18.2  35.4
# 42547  2022/11/13 20:00:00+00  18.8  21.8  29.6
# 42548  2022/11/13 21:00:00+00  19.4  29.9  32.1
# 42549  2022/11/13 22:00:00+00  22.8  23.2  29.4
# 42550  2022/11/13 23:00:00+00  20.8  20.9  30.1
#
# [42551 rows x 4 columns] without scaling it, now you can play with data viz functions
#        Date_time   PM25   PM10   NO2  ATMO
# 0     2018/01/01    NaN    NaN   NaN   NaN
# 1     2018/01/02    NaN    NaN   NaN   NaN
# 2     2018/01/03    NaN    NaN   NaN   NaN
# 3     2018/01/04    NaN    NaN   NaN   NaN
# 4     2018/01/05  12.69  27.38   NaN   0.0
# ...          ...    ...    ...   ...   ...
# 1770  2022/11/09   9.46  20.89  84.7   0.0
# 1771  2022/11/10  13.11  24.36  86.4   0.0
# 1772  2022/11/11  10.79  15.25  52.5   0.0
# 1773  2022/11/12  23.87  37.09  97.0   1.0
# 1774  2022/11/13  24.85  34.48  73.3   1.0
#
# [1775 rows x 5 columns]

# %%
from workflow.data_viz import data_viz
data_viz_test = data_viz(df_13_preprocessed_w_scaling)
data_viz_test
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:13: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week"] = df["Date_time"].dt.week
#       Date_time   PM25   PM10   NO2  ATMO  year  week  day  month  \
# 0    2018-01-01    NaN    NaN   NaN   NaN  2018     1    1      1
# 1    2018-01-02    NaN    NaN   NaN   NaN  2018     1    2      1
# 2    2018-01-03    NaN    NaN   NaN   NaN  2018     1    3      1
# 3    2018-01-04    NaN    NaN   NaN   NaN  2018     1    4      1
# 4    2018-01-05  12.69  27.38   NaN   0.0  2018     1    5      1
# ...         ...    ...    ...   ...   ...   ...   ...  ...    ...
# 1770 2022-11-09   9.46  20.89  84.7   0.0  2022    45    9     11
# 1771 2022-11-10  13.11  24.36  86.4   0.0  2022    45   10     11
# 1772 2022-11-11  10.79  15.25  52.5   0.0  2022    45   11     11
# 1773 2022-11-12  23.87  37.09  97.0   1.0  2022    45   12     11
# 1774 2022-11-13  24.85  34.48  73.3   1.0  2022    45   13     11
#
#       weekday_name
# 0                0
# 1                1
# 2                2
# 3                3
# 4                4
# ...            ...
# 1770             2
# 1771             3
# 1772             4
# 1773             5
# 1774             6
#
# [1775 rows x 10 columns]

# %%
data_viz_test.ATMO.value_counts()
# Out:
# 1.0    673
# 2.0    643
# 0.0    449
# Name: ATMO, dtype: int64

# %%
from workflow.data_viz import plot_pollutant_v1



plot_pollutant_v1(data_viz_test,"ATMO","month")
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:49: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_groupby = df.groupby(by=["year",period],as_index=False).mean()

# %%
from workflow.data_viz import plot_pollutant_v2


plot_pollutant_v2(data_viz_test,"ATMO","week")
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:139: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_groupby = df.groupby(by=["year",period],as_index=False).mean()

# %%
from workflow.data_viz import weekday_pollutant

weekday_pollutant(df_13_preprocessed_w_scaling,"ATMO")

# %%
from workflow.data_viz import plot_shift_pollutant

plot_shift_pollutant(df_13_preprocessed_w_scaling,"NO2","2019")
# Out:
# /Users/Edouard_1/code/TheLab75/ParisDeepAirProject/workflow/data_viz.py:275: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["mean_shift"]=df[["J-1","J-2","J-3","J-4","J-5","J-6","J-7"]].mean(axis=1)

# %%
# !pip install FastAPI
# Out:
# Collecting FastAPI
#   Downloading fastapi-0.88.0-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 133.6 kB/s eta 0:00:00 kB/s eta 0:00:01
# Collecting starlette==0.22.0
#   Downloading starlette-0.22.0-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 1.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2
#   Using cached pydantic-1.10.2-cp310-cp310-macosx_11_0_arm64.whl (2.6 MB)
# Requirement already satisfied: anyio<5,>=3.4.0 in /Users/Edouard_1/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from starlette==0.22.0->FastAPI) (3.6.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/Edouard_1/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from pydantic!=1.7,!=1.7.1,!=1.7.2,!=1.7.3,!=1.8,!=1.8.1,<2.0.0,>=1.6.2->FastAPI) (4.4.0)
# Requirement already satisfied: idna>=2.8 in /Users/Edouard_1/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->FastAPI) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/Edouard_1/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette==0.22.0->FastAPI) (1.3.0)
# Installing collected packages: pydantic, starlette, FastAPI
# Successfully installed FastAPI-0.88.0 pydantic-1.10.2 starlette-0.22.0

# %%
! pip install uvicorn
# Out:
# Collecting uvicorn
#   Using cached uvicorn-0.20.0-py3-none-any.whl (56 kB)
# Collecting h11>=0.8
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Installing collected packages: h11, click, uvicorn
# Successfully installed click-8.1.3 h11-0.14.0 uvicorn-0.20.0

# %%
from datetime import datetime
import pandas as pd

from fastapi import FastAPI

from fastapi.middleware.cors import CORSMiddleware



app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],  # Allows all origins
    allow_credentials=True,
    allow_methods=["*"],  # Allows all methods
    allow_headers=["*"],  # Allows all headers
)

from workflow.data_viz import plot_pollutant_v1
from workflow.data_viz import plot_pollutant_v2
from workflow.data_viz import weekday_pollutant
from workflow.data_viz import plot_shift_pollutant

@app.get("/data_viz")
def data_viz(df,pollutant,period,choice_of_plot,year):
    #On doit faire choisir à l'utilisateur la station
    #Puis lui monter dans une liste déroulante, les polluants disponibles

    if choice_of_plot == "All in one graph":
        plot = plot_pollutant_v1(df,pollutant,period)

    elif choice_of_plot == "1 graph for one year":
        plot = plot_pollutant_v2(df,pollutant,period)

    elif choice_of_plot == " Week day":
        plot = weekday_pollutant(df,pollutant)


    elif choice_of_plot == "Shifting":
        #on doit faire sélectionenr à l'utilisateur une année afin de plot l'année sélectionnée
        plot = plot_shift_pollutant(df,year)


    return plot

# %%
df_13
# Out:
#                     Date_time  PM25  PM10   NO2  O3  SO2  \
# 0      2018/01/01 01:00:00+00   NaN   NaN   NaN NaN  NaN
# 1      2018/01/01 02:00:00+00   NaN   NaN   NaN NaN  NaN
# 2      2018/01/01 03:00:00+00   NaN   NaN   NaN NaN  NaN
# 3      2018/01/01 04:00:00+00   NaN   NaN   NaN NaN  NaN
# 4      2018/01/01 05:00:00+00   NaN   NaN   NaN NaN  NaN
# ...                       ...   ...   ...   ...  ..  ...
# 42571  2022/11/14 20:00:00+00  14.5  18.8  41.5 NaN  NaN
# 42572  2022/11/14 21:00:00+00   NaN   NaN  34.5 NaN  NaN
# 42573  2022/11/14 22:00:00+00   NaN   NaN   NaN NaN  NaN
# 42574  2022/11/14 23:00:00+00   NaN   NaN   NaN NaN  NaN
# 42575  2022/11/15 00:00:00+00   NaN   NaN   NaN NaN  NaN
#
#                 Station_name Station_type
# 0      75016 - Porte Auteuil      Traffic
# 1      75016 - Porte Auteuil      Traffic
# 2      75016 - Porte Auteuil      Traffic
# 3      75016 - Porte Auteuil      Traffic
# 4      75016 - Porte Auteuil      Traffic
# ...                      ...          ...
# 42571  75016 - Porte Auteuil      Traffic
# 42572  75016 - Porte Auteuil      Traffic
# 42573  75016 - Porte Auteuil      Traffic
# 42574  75016 - Porte Auteuil      Traffic
# 42575  75016 - Porte Auteuil      Traffic
#
# [42576 rows x 8 columns]

# %%
# import requests

url = 'http://localhost:8000/data_viz'

#Créer une liste avec les data frames de chaque station : 



params = {
    'df': df_13 , 
    'pollutant': "NO2",
    'period':'month',
    'choice_of_plot':'All in one graph',
    'year':'2019'
}


response = requests.get(url, params=params)
response.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[63], line 19
#       9 params = {
#      10     'df': df_13 ,
#      11     'pollutant': "NO2",
#    (...)
#      14     'year':'2019'
#      15 }
#      18 response = requests.get(url, params=params)
# ---> 19 response.json()
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
