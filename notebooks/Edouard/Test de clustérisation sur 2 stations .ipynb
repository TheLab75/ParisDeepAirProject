# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd 

df_1 = pd.read_csv("/Users/Edouard_1/code/TheLab75/ParisDeepAirProject/data/pollution/2_Processed/PA75016.csv").copy()
df_2 = pd.read_csv("/Users/Edouard_1/code/TheLab75/ParisDeepAirProject/data/pollution/2_Processed/PA75015.csv").copy()
                   

df_merge = pd.merge(df_1,df_2,how="outer", on="Date_time")
d

df_merge





df_merge["Mean_PM25"] = df_merge[["PM25_x","PM25_y"]].mean(skipna=True,axis=1)
df_mergex

df_merge["Mean_PM25"]


df_merge.sample(5)
# Out:
#                     Date_time  PM25_x  PM10_x  NO2_x  O3_x  SO2_x  \
# 1523   2018/03/05 12:00:00+00    10.8    52.7   79.0   NaN    2.0
# 8785   2019/01/02 02:00:00+00     5.3    20.9   33.5   NaN    0.0
# 34732  2021/12/23 05:00:00+00    29.4    33.3   33.7   NaN    NaN
# 376    2018/01/16 17:00:00+00    11.5    31.5  108.0   NaN    1.0
# 22012  2020/07/09 05:00:00+00    16.0    52.9   82.9   NaN    5.9
#
#               Station_name_x Station_type_x  PM25_y  PM10_y  NO2_y  O3_y  \
# 1523   75016 - Porte Auteuil        Traffic     NaN    15.0   35.0   NaN
# 8785   75016 - Porte Auteuil        Traffic     NaN    14.7    8.1   NaN
# 34732  75016 - Porte Auteuil        Traffic     NaN    29.9   31.2   NaN
# 376    75016 - Porte Auteuil        Traffic     NaN     8.3   36.0   NaN
# 22012  75016 - Porte Auteuil        Traffic     NaN     8.6   12.1   NaN
#
#        SO2_y   Station_name_y Station_type_y  Mean_PM25
# 1523     NaN  75015 - Lenglen         Urbain       10.8
# 8785     NaN  75015 - Lenglen         Urbain        5.3
# 34732    NaN  75015 - Lenglen         Urbain       29.4
# 376      NaN  75015 - Lenglen         Urbain       11.5
# 22012    NaN  75015 - Lenglen         Urbain       16.0

# %%
cluster1_O = ['PA75007_1', 'PA75007_2', 'PA75016', 'PA92220', 'PA92800' ]
cluster2_N = ['PA75018', 'PA93300', 'PA93500']
cluster3_E = ['PA75012_1', 'PA75012_2', 'PA75012_3']
cluster4_S = ['PA75013', 'PA75014', 'PA75015']
cluster5_C = ['PA75001', 'PA75002', 'PA75004', 'PA75006', 'PA75008', 'PA75009']

df_1 = pd.read_csv(f"../../data/pollution/2_Processed/{cluster1_O[0]}.csv").copy()
df_2 = pd.read_csv(f"../../data/pollution/2_Processed/{cluster1_O[1]}.csv").copy()
df_3 = pd.read_csv(f"../../data/pollution/2_Processed/{cluster1_O[2]}.csv").copy()
df_4 = pd.read_csv(f"../../data/pollution/2_Processed/{cluster1_O[3]}.csv").copy()
df_5 = pd.read_csv(f"../../data/pollution/2_Processed/{cluster1_O[4]}.csv").copy()

# %%
df_merge = pd.merge(df_1,df_2, how="outer",on="Date_time")
df_merge = pd.merge(df_merge,df_3, how="outer",on="Date_time")
df_merge= pd.merge(df_merge,df_4, how="outer",on="Date_time")
df_merge= pd.merge(df_merge,df_5, how="outer",on="Date_time")
df_merge.columns
# Out:
# /var/folders/5r/4vh837mj0yz7906w_9ntwqfm0000gn/T/ipykernel_15569/3051695409.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'NO2_x', 'Station_type_x', 'Station_name_x', 'PM10_x', 'O3_x', 'PM25_x', 'SO2_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merge= pd.merge(df_merge,df_4, how="outer",on="Date_time")
# Index(['Date_time', 'PM25_x', 'PM10_x', 'NO2_x', 'O3_x', 'SO2_x',
#        'Station_name_x', 'Station_type_x', 'PM25_y', 'PM10_y', 'NO2_y', 'O3_y',
#        'SO2_y', 'Station_name_y', 'Station_type_y', 'PM25_x', 'PM10_x',
#        'NO2_x', 'O3_x', 'SO2_x', 'Station_name_x', 'Station_type_x', 'PM25_y',
#        'PM10_y', 'NO2_y', 'O3_y', 'SO2_y', 'Station_name_y', 'Station_type_y',
#        'PM25', 'PM10', 'NO2', 'O3', 'SO2', 'Station_name', 'Station_type'],
#       dtype='object')

# %%
df_merge["Mean_PM25"] = df_merge[["PM25_x","PM25_y","PM25"]].mean(skipna=True,axis=1)
df_merge["Mean_PM10"] = df_merge[["PM10_x","PM10_y","PM10"]].mean(skipna=True,axis=1)
df_merge["Mean_NO2"] = df_merge[["NO2_x","NO2_y","NO2"]].mean(skipna=True,axis=1)
df_merge["Mean_O3"] = df_merge[["O3_x","O3_y","O3"]].mean(skipna=True,axis=1)
df_merge["Mean_SO2"] = df_merge[["SO2_x","SO2_y","SO2"]].mean(skipna=True,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 df_merge["Mean_PM25"] = df_merge[["PM25_x","PM25_y","PM25"]].mean(skipna=True,axis=1)
#       2 df_merge["Mean_PM10"] = df_merge[["PM10_x","PM10_y","PM10"]].mean(skipna=True,axis=1)
#       3 df_merge["Mean_NO2"] = df_merge[["NO2_x","NO2_y","NO2"]].mean(skipna=True,axis=1)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/frame.py:3811, in DataFrame.__getitem__(self, key)
#    3809     if is_iterator(key):
#    3810         key = list(key)
# -> 3811     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3813 # take() does not accept boolean indexers
#    3814 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6113, in Index._get_indexer_strict(self, key, axis_name)
#    6110 else:
#    6111     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6113 self._raise_if_missing(keyarr, indexer, axis_name)
#    6115 keyarr = self.take(indexer)
#    6116 if isinstance(key, Index):
#    6117     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6173, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     if use_interval_msg:
#    6172         key = list(key)
# -> 6173     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6175 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6176 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['PM25_x', 'PM25_y', 'PM25'], dtype='object')] are in the [columns]"

# %%
#df_merge = df_merge.drop(columns=["PM25_x","PM25_y","PM25"])
df_merge = df_merge.drop(columns=["PM10_x","PM10_y","PM10"])
df_merge = df_merge.drop(columns=["NO2_x","NO2_y","NO2"])
df_merge = df_merge.drop(columns=["O3_x","O3_y","O3"])
df_merge = df_merge.drop(columns=["SO2_x","SO2_y","SO2"])
df_merge = df_merge.drop(columns=["Station_name_x","Station_name_y","Station_name"])
df_merge = df_merge.drop(columns=["Station_type_x","Station_type_y","Station_type"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 2
#       1 #df_merge = df_merge.drop(columns=["PM25_x","PM25_y","PM25"])
# ----> 2 df_merge = df_merge.drop(columns=["PM10_x","PM10_y","PM10"])
#       3 df_merge = df_merge.drop(columns=["NO2_x","NO2_y","NO2"])
#       4 df_merge = df_merge.drop(columns=["O3_x","O3_y","O3"])
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/generic.py:4575, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4573     labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    4574     if errors == "raise" and labels_missing:
# -> 4575         raise KeyError(f"{labels} not found in axis")
#    4577 if is_extension_array_dtype(mask.dtype):
#    4578     # GH#45860
#    4579     mask = mask.to_numpy(dtype=bool)
#
# KeyError: "['PM10_x' 'PM10_y' 'PM10'] not found in axis"

# %%
df_merge = df_merge.drop(columns=["Station_name_x","Station_name_y","Station_name"])
df_merge = df_merge.drop(columns=["Station_type_x","Station_type_y","Station_type"])

df_merge[100]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df_merge = df_merge.drop(columns=["Station_name_x","Station_name_y","Station_name"])
#       2 df_merge = df_merge.drop(columns=["Station_type_x","Station_type_y","Station_type"])
#       4 df_merge[100]
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~/.pyenv/versions/3.10.6/envs/PDPA-virt_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['Station_name_x', 'Station_name_y', 'Station_name'] not found in axis"

# %%
df_merge
# Out:
#                     Date_time  Mean_PM25  Mean_PM10   Mean_NO2  Mean_O3  \
# 0      2018/01/01 01:00:00+00        NaN       12.6   6.000000     77.5
# 1      2018/01/01 02:00:00+00        NaN       10.1   6.000000     78.5
# 2      2018/01/01 03:00:00+00        NaN       11.3   7.000000     74.0
# 3      2018/01/01 04:00:00+00        NaN       10.2   8.333333     71.0
# 4      2018/01/01 05:00:00+00        NaN       11.6   7.000000     71.5
# ...                       ...        ...        ...        ...      ...
# 42691  2021/02/14 20:00:00+00      24.10       36.7  34.725000     44.1
# 42692  2021/02/14 21:00:00+00      25.05       38.7  36.975000     39.6
# 42693  2021/02/14 22:00:00+00      28.25       34.3  35.000000     36.9
# 42694  2021/02/14 23:00:00+00      29.30       37.5  34.850000     32.9
# 42695  2021/02/15 00:00:00+00      27.55       41.9  32.550000     32.5
#
#        Mean_SO2
# 0           1.5
# 1           1.0
# 2           1.5
# 3           1.5
# 4           1.0
# ...         ...
# 42691       NaN
# 42692       NaN
# 42693       NaN
# 42694       NaN
# 42695       NaN
#
# [42696 rows x 6 columns]
