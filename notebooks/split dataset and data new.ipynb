# %%
import pandas as pd

# %%
LOCAL_DATA_PATH_3 = 'data/pollution/5_Clusters'

# %%
df = pd.read_csv(f"../{LOCAL_DATA_PATH_3}/cluster1_Ouest.csv", index_col='Date_time').copy()
df
# Out:
#              PM25   PM10    NO2     O3  Pollution_peak  ATMO  sin_Month  \
# Date_time
# 2018-01-01  12.90   8.74  14.33  78.50               0     0   0.000000
# 2018-01-02  12.90  13.56  34.67  71.00               0     0   0.000000
# 2018-01-03  12.90  12.80  24.25  80.50               0     0   0.000000
# 2018-01-04  12.90   9.09  25.25  69.00               0     0   0.000000
# 2018-01-05  12.79  15.81  46.75  79.50               0     0   0.000000
# ...           ...    ...    ...    ...             ...   ...        ...
# 2022-11-30  17.67  31.65  46.58  42.15               0     0  -0.866025
# 2022-12-01  22.85  32.04  38.62  25.10               0     1  -0.500000
# 2022-12-02  28.70  35.24  39.72  24.95               0     2  -0.500000
# 2022-12-03  19.83  23.61  32.00  13.55               0     0  -0.500000
# 2022-12-04  24.10  31.37  34.75  14.90               0     1  -0.500000
#
#             cos_Month   sin_day   cos_day  confinement
# Date_time
# ...

# %%
df_split = df[-7:]

# %%
df_split
# Out:
#              PM25   PM10    NO2     O3  Pollution_peak  ATMO  sin_Month  \
# Date_time
# 2022-11-28  12.32  24.10  48.65  53.60               0     0  -0.866025
# 2022-11-29  17.04  27.27  69.00  47.00               0     0  -0.866025
# 2022-11-30  17.67  31.65  46.58  42.15               0     0  -0.866025
# 2022-12-01  22.85  32.04  38.62  25.10               0     1  -0.500000
# 2022-12-02  28.70  35.24  39.72  24.95               0     2  -0.500000
# 2022-12-03  19.83  23.61  32.00  13.55               0     0  -0.500000
# 2022-12-04  24.10  31.37  34.75  14.90               0     1  -0.500000
#
#             cos_Month   sin_day   cos_day  confinement
# Date_time
# 2022-11-28   0.500000 -0.781831  0.623490            0
# 2022-11-29   0.500000  0.000000  1.000000            0
# 2022-11-30   0.500000  0.781831  0.623490            0
# 2022-12-01   0.866025  0.974928 -0.222521            0
# 2022-12-02   0.866025  0.433884 -0.900969            0
# ...

# %%
df_train = df[:-7]

# %%
df_split = df[-7:]
df_train = [:-7]

cluster1_Ouest_test = df_split
# Out:
#   Cell In[14], line 2
#     df_train = [:-7]
#                 ^
# SyntaxError: invalid syntax

# %%
cluster1_Ouest_test
# Out:
#        Date_time   PM25   PM10    NO2     O3  Pollution_peak  ATMO  sin_Month  \
# 1792  2022-11-28  12.32  24.10  48.65  53.60               0     0  -0.866025
# 1793  2022-11-29  17.04  27.27  69.00  47.00               0     0  -0.866025
# 1794  2022-11-30  17.67  31.65  46.58  42.15               0     0  -0.866025
# 1795  2022-12-01  22.85  32.04  38.62  25.10               0     1  -0.500000
# 1796  2022-12-02  28.70  35.24  39.72  24.95               0     2  -0.500000
# 1797  2022-12-03  19.83  23.61  32.00  13.55               0     0  -0.500000
# 1798  2022-12-04  24.10  31.37  34.75  14.90               0     1  -0.500000
#
#       cos_Month   sin_day   cos_day  confinement
# 1792   0.500000 -0.781831  0.623490            0
# 1793   0.500000  0.000000  1.000000            0
# 1794   0.500000  0.781831  0.623490            0
# 1795   0.866025  0.974928 -0.222521            0
# 1796   0.866025  0.433884 -0.900969            0
# ...

# %%
df_split.to_csv('../data/pollution/6_Clusters_split/cluster1_Ouest_test.csv', index=True)

# %%
df_train.to_csv('../data/pollution/6_Clusters_split/cluster1_Ouest_train.csv', index=True)

# %%
# Station

# %%
df_2 = pd.read_csv(f"../{LOCAL_DATA_PATH_3}/cluster2_Nord.csv").copy()

# %%
df_2 = pd.read_csv(f"../{LOCAL_DATA_PATH_3}/cluster2_Nord.csv",index_col='Date_time').copy()
df_2
# Out:
#              PM10    NO2    O3  ATMO  sin_Month  cos_Month   sin_day  \
# Date_time
# 2018-01-01  12.04  37.00  66.0     0   0.000000   1.000000 -0.781831
# 2018-01-02  18.87  60.67  62.0     0   0.000000   1.000000  0.000000
# 2018-01-03  16.42  36.67  70.0     0   0.000000   1.000000  0.781831
# 2018-01-04  10.86  55.67  57.0     0   0.000000   1.000000  0.974928
# 2018-01-05  15.95  73.00  71.0     0   0.000000   1.000000  0.433884
# ...           ...    ...   ...   ...        ...        ...       ...
# 2022-11-30  24.61  50.73  44.6     0  -0.866025   0.500000  0.781831
# 2022-12-01  28.09  37.23  15.5     0  -0.500000   0.866025  0.974928
# 2022-12-02  34.29  38.37  20.5     0  -0.500000   0.866025  0.433884
# 2022-12-03  19.81  29.40  14.7     0  -0.500000   0.866025 -0.433884
# 2022-12-04  24.78  34.73  16.2     0  -0.500000   0.866025 -0.974928
#
#              cos_day  confinement
# Date_time
# 2018-01-01  0.623490            0
# 2018-01-02  1.000000            0
# ...

# %%
df_test_2 = df[-7:]
df_train_2 = df[:-7]

# %%
df_train_2.to_csv('../data/pollution/6_Clusters_split/cluster2_Nord_train.csv', index=True)

# %%
df_test_2.to_csv('../data/pollution/6_Clusters_split/cluster2_Nord_test.csv', index=True)

# %%
# station 3

# %%
df_3 = pd.read_csv(f"../{LOCAL_DATA_PATH_3}/cluster1_Ouest.csv", index_col='Date_time').copy()
df_3

# %%
df = pd.read_csv(f"../{LOCAL_DATA_PATH_3}/cluster1_Ouest.csv", index_col='Date_time').copy()
df
# Out:
#              PM25   PM10    NO2     O3  Pollution_peak  ATMO  sin_Month  \
# Date_time
# 2018-01-01  12.90   8.74  14.33  78.50               0     0   0.000000
# 2018-01-02  12.90  13.56  34.67  71.00               0     0   0.000000
# 2018-01-03  12.90  12.80  24.25  80.50               0     0   0.000000
# 2018-01-04  12.90   9.09  25.25  69.00               0     0   0.000000
# 2018-01-05  12.79  15.81  46.75  79.50               0     0   0.000000
# ...           ...    ...    ...    ...             ...   ...        ...
# 2022-11-30  17.67  31.65  46.58  42.15               0     0  -0.866025
# 2022-12-01  22.85  32.04  38.62  25.10               0     1  -0.500000
# 2022-12-02  28.70  35.24  39.72  24.95               0     2  -0.500000
# 2022-12-03  19.83  23.61  32.00  13.55               0     0  -0.500000
# 2022-12-04  24.10  31.37  34.75  14.90               0     1  -0.500000
#
#             cos_Month   sin_day   cos_day  confinement
# Date_time
# ...

# %%
df['ATMO'] = df['ATMO'].apply(atmo)

# %%
def atmo(x):
    return x+1

# %%
df
# Out:
#              PM25   PM10    NO2     O3  Pollution_peak  ATMO  sin_Month  \
# Date_time
# 2018-01-01  12.90   8.74  14.33  78.50               0     1   0.000000
# 2018-01-02  12.90  13.56  34.67  71.00               0     1   0.000000
# 2018-01-03  12.90  12.80  24.25  80.50               0     1   0.000000
# 2018-01-04  12.90   9.09  25.25  69.00               0     1   0.000000
# 2018-01-05  12.79  15.81  46.75  79.50               0     1   0.000000
# ...           ...    ...    ...    ...             ...   ...        ...
# 2022-11-30  17.67  31.65  46.58  42.15               0     1  -0.866025
# 2022-12-01  22.85  32.04  38.62  25.10               0     2  -0.500000
# 2022-12-02  28.70  35.24  39.72  24.95               0     3  -0.500000
# 2022-12-03  19.83  23.61  32.00  13.55               0     1  -0.500000
# 2022-12-04  24.10  31.37  34.75  14.90               0     2  -0.500000
#
#             cos_Month   sin_day   cos_day  confinement
# Date_time
# ...

# %%
df.to_csv('../data/pollution/6_Clusters_split/cluster1_Ouest_new_atmo.csv', index=True)

# %%
# station 2
